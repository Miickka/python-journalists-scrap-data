# %% [markdown]
# # Scrape data with Python Requests and Beautiful Soup

# %% [markdown]
# Welcome to this Jupyter Notebook!
#
# This notebook was made for the Datajournalism.com [course Python for Journalists](https://datajournalism.com/watch/python-for-journalists). In this module you'll learn how to instruct your computer to download structured, not password protected data from the internet; a technique also known as webscraping. We'll be using the libraries Requests and Beautiful Soup to scrape data. Don't forget to install these libraries to your Anaconda environment. (Otherwise importing these libraries will result in an error message.) Installating these libraries needs to be done in the terminal/cmd prompt using the commands `conda install requests` and `conda install bs4`.
#
#
# ## About Jupyter Notebooks and Pandas
#
# Right now you're looking at a Jupyter Notebook: an interactive, browser based programming environment. You can use these notebooks to program in R, Julia or Python - as you'll be doing later on. Read more about Jupyter Notebook in the [Jupyter Notebook Quick Start Guide](https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html).
#
# To clean up our data, we'll be using Python and Pandas. Pandas is an open-source Python library - basically an extra toolkit to go with Python - that is designed for data analysis. Pandas is flexible, easy to use and has lots of useful functions built right in. Read more about Pandas and its features in [the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/).
#
# **Notebook shortcuts**
#
# Within Jupyter Notebooks, there are some shortcuts you can use. If you'll be using more notebooks for your data analysis in the future, you'll remember these shortcuts soon enough. :)
#
# * `esc` will take you into command mode
# * `a` will insert cell above
# * `b` will insert cell below
# * `shift then tab` will show you the documentation for your code
# * `shift and enter` will run your cell
# * ` d d` will delete a cell
#
# **Pandas dictionary**
#
# * **dataframe**: dataframe is Pandas speak for a table with a labeled y-axis, also known as an index. (The index usually starts at 0.)
# * **series**: a series is a list, a series can be made of a single column within a dataframe.
#
# Before we dive in, a little more about Jupyter Notebooks. Every notebooks is made out of cells. A cell can either contain Markdown text - like this one - or code. In the latter you can execute your code. To see what that means, type the following command in the next cell `print("hello world")`.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Getting started

# %% [markdown]
# Now, let's import the libraries we need to get started with scraping. Type `import requests`, `from bs4 import BeautifulSoup`, `import pandas as pd` and `import csv`.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %% [markdown]
# **What's in a name**
# Scraping is the act of automatically downloading selected data from a website. Scraping is also known as web scraping, web harvesting, web data extraction and data scraping. It can be very valueable tool for your newsroom: instead of by hand saving data from the web, you can automate and speed up the process by writing a custom Python program that downloads the information for you.
#
#
#
#
# **What we'll actually will be doing, when I say 'we're scraping a website':**
#
# - tell your computer which site to visit: where do you want to download data from?
#     - we'll be using the `requests` library to requests webpages
# - save the webpage (the html-page) to the computer
#     - this too will be done with library `requests`
# - from the webpage, select the data you want to have
#     - we'll be using `BeautifulSoup` to do this
# - write the selection to a csv-file
#     - this is done with the `csv` library
#
# If there is more than 1 page where you want to get data from, you can tell your computer to move on the next page to repeat the process. But that's for another course... :)

# %% [markdown]
# # Scraping a website
#
# ## Request webpage
# We'll be scraping a list of [Power Reactors](https://www.nrc.gov/reactors/operating/list-power-reactor-units.html) from the site of the US government. First we need to let our computer know what site we want to visit; than we can request the site using `requests.get('http://website.com')`.

# %%
page = requests.get('https://www.nrc.gov/reactors/operating/list-power-reactor-units.html')

# %% [markdown]
# If you want your code to become more easily reusable, you can rewrite to:

# %%
url = 'https://www.nrc.gov/reactors/operating/list-power-reactor-units.html'
page = requests.get(url)

# %% [markdown]
# Note that `requests.get(url)` doesn't have the url in quotes; it's clear the url is a string by the quotation marks in `url = 'https://www.nrc.gov/reactors/operating/list-power-reactor-units.html'`.
#
# To check if everything went right, we can use simpy type `page`; this will return a response code. Status codes are issued by a server in response to a client's request made to the server. Read more about these code on the [wikipedia page on status codes](). Basically, if you have a 200 response code, the website loaded in just fine.

# %%
page
# Out:
# <Response [200]>

# %% [markdown]
# ## Parse HTML, select data
# Now that we've got the page, let's parse the htmlpage. To parse is just nerd speak for splitting up the original data in smaller bits. Use `BeautifulSoup(page.content, 'html.parser')`. It's pretty common when scraping, to name the first with BeautifulSoup created file 'soup'. This 'soup' variable will contain all html of the page once we're done.
#
# Off course, if you want to see what is in 'soup', you could type `print(soup)`. (Notice how there are no quotemarks, since the soup we're refering to is a variable that has data stored inside of it and it is not a string. But, when you add `soup` on a new line, the computer will also print your soup. Again: programmers like things short and sweet.
#
# Btw, the library is named after the Beautiful Soup from Alice in Wonderland... Not kidding.
#
# Now, let's make ourselves some soup...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# Next you want to select the table from this soup. Thanks to the BeautifulSoup library, you can do this writing `soup.find('table')`, this command will look for the first `<table>` in the source code of the webpage, also known as our soup.

# %%
table = soup.find('table')
table
# Out:
# <table border="1" cellpadding="5" cellspacing="0" summary="List of Power Reactor Units" width="100%">
# <tbody>
# <tr valign="top">
# <th scope="col">Plant Name<br/>
# 			Docket Number</th>
# <th scope="col">License Number</th>
# <th scope="col">Reactor<br/>
# 			Type</th>
# <th scope="col">Location</th>
# <th scope="col">Owner/Operator</th>
# <th scope="col">NRC Region</th>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/ano1.html">Arkansas Nuclear 1</a><br/>
# 			05000313</td>
# <td align="center">DPR-51</td>
# <td>PWR</td>
# <td>6 miles WNW of Russellville,  AR</td>
# <td>Entergy Nuclear Operations, Inc.</td>
# <td align="middle">4</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/ano2.html">Arkansas Nuclear 2</a><br/>
# 			05000368</td>
# <td align="center">NPF-6</td>
# <td>PWR</td>
# <td>6 miles WNW of Russellville,  AR</td>
# <td>Entergy Nuclear Operations, Inc.</td>
# <td align="middle">4</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/bv1.html">Beaver Valley 1</a><br/>
# 			05000334</td>
# <td align="center">DPR-66</td>
# <td>PWR</td>
# <td>17 miles W of McCandless,  PA</td>
# <td>FirstEnergy Nuclear Operating Co.</td>
# <td align="middle">1</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/bv2.html">Beaver Valley 2</a><br/>
# 			05000412</td>
# <td align="center">NPF-73</td>
# <td>PWR</td>
# <td>17 miles W of McCandless,  PA</td>
# <td>FirstEnergy Nuclear Operating Co.</td>
# <td align="middle">1</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/brai1.html">Braidwood 1</a><br/>
# 			05000456</td>
# <td align="center">NPF-72</td>
# <td>PWR</td>
# <td>20 miles SSW of Joliet,  IL</td>
# <td>Exelon Generation Co., LLC</td>
# <td align="middle">3</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors
>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/vog1.html">Vogtle 1</a><br/>
# 			05000424</td>
# <td align="center">NPF-68</td>
# <td>PWR</td>
# <td>26 miles SE of Augusta,  GA</td>
# <td>Southern Nuclear Operating Co.</td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/vog2.html">Vogtle 2</a><br/>
# 			05000425</td>
# <td align="center">NPF-81</td>
# <td>PWR</td>
# <td>26 miles SE of Augusta,  GA</td>
# <td>Southern Nuclear Operating Co.</td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wat3.html">Waterford 3</a><br/>
# 			05000382</td>
# <td align="center">NPF-38</td>
# <td>PWR</td>
# <td>25 miles W of New Orleans,  LA</td>
# <td>Entergy Nuclear Operations, Inc.</td>
# <td align="middle">4</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wb1.html">Watts Bar 1</a><br/>
# 			05000390</td>
# <td align="center">NPF-90</td>
# <td>PWR</td>
# <td>60 miles SW of Knoxville, TN</td>
# <td>Tennessee Valley Authority</td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wb2.html">Watts Bar 2</a><br/>
# 			05000391</td>
# <td align="center">NPF-96</td>
# <td>PWR</td>
# <td>60 miles SW of Knoxville, TN</td>
# <td>Tennessee Valley Authority</td>
# <td align="middle">2</td>
# </tr>
# <tr valign="top">
# <td scope="row"><a href="/info-finder/reactors/wc.html">Wolf Creek 1</a><br/>
# 			05000482</td>
# <td align="center">NPF-42</td>
# <td>PWR</td>
# <td>3.5 miles NE of Burlington,  KS</td>
# <td>Wolf Creek Nuclear Operating Corp.</td>
# <td align="middle">4</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Next, let's get all rows in the table. The HTML code for rows in a table is `<tr>`. We can use the BeautifulSoup command `.find_all('tr')` to get all of these rows.

# %%
rows = table.find_all('tr')
rows
# Out:
# [<tr valign="top">
#  <th scope="col">Plant Name<br/>
#  			Docket Number</th>
#  <th scope="col">License Number</th>
#  <th scope="col">Reactor<br/>
#  			Type</th>
#  <th scope="col">Location</th>
#  <th scope="col">Owner/Operator</th>
#  <th scope="col">NRC Region</th>
#  </tr>,
#  <tr valign="top">
#  <td scope="row"><a href="/info-finder/reactors/ano1.html">Arkansas Nuclear 1</a><br/>
#  			05000313</td>
#  <td align="center">DPR-51</td>
#  <td>PWR</td>
#  <td>6 miles WNW of Russellville,  AR</td>
#  <td>Entergy Nuclear Operations, Inc.</td>
#  <td align="middle">4</td>
#  </tr>,
#  <tr valign="top">
#  <td scope="row"><a href="/info-finder/reactors/ano2.html">Arkansas Nuclear 2</a><br/>
#  			05000368</td>
#  <td align="center">NPF-6</td>
#  <td>PWR</td>
#  <td>6 miles WNW of Russellville,  AR</td>
#  <td>Entergy Nuclear Operations, Inc.</td>
#  <td align="middle">4</td>
#  </tr>,
#  <tr valign="top">
#  <td scope="row"><a href="/info-finder/reactors/bv1.html">Beaver Valley 1</a><br/>
#  			05000334</td>
#  <td align="center">DPR-66</td>
#  <td>PWR</td>
#  <td>17 miles W of McCandless,  PA</td>
#  <td>FirstEnergy Nuclear Operating Co.</td>
#  <td align="middle">1</td>
#  </tr>,
#  <tr valign="top">
#  <td scope="row"><a href="/info-finder/reactors/bv2.html">Beaver Valley 2</a><br/>
#  			05000412</td>
#  <td align="center">NPF-73</td>
#  <td>PWR</td>
#  <td>17 miles W of McCandless,  PA</td>
#  <td>FirstEnergy Nuclear Operating Co.</td>
#  <td align="middle">1</td>
#  </tr>,
#  <tr valign="top">
#  <td scope="row"><a href="/info-finder/reactors/brai1.html">Braidwood 1</a><br/>
#  			05000456</td>
#  <td align="center">NPF-72</td>
#  <td>PWR</td>
#  <td>20 miles SSW of Joliet,  IL</td>
#  <td>Exelon Generation Co., LLC</td>
#  <td align="middle">3</td>
#  </tr>,
#  <tr valign="top">
#  <td scope="row"><a href="/info-finder/reactors
#  <td>3.5 miles NE of Burlington,  KS</td>
#  <td>Wolf Creek Nuclear Operating Corp.</td>
#  <td align="middle">4</td>
#  </tr>]

# %% [markdown]
# See how with `.find_all('')` you can find all rows at once, while `.find('')` will just get you the first one of whatever it is your looking for.
#
# Since there is only 1 table on this webpage, you can either use `soup.find_all('tr')` or `table.find_all('tr')`. But if there are two or more tables on one page, the `soup.find_all('tr')` command will get you all rows, from all tables. `table.find_all('tr')` builds upon `soup.find('table')`, which will give you the **first** table; meaning that `table.find_all('tr')` will get all rows from the first table only.
#
# Don't believe me? Let's try and use `soup.find_all('tr')`...

# %% [markdown]
# You see? Exactly the same result. Just remember; whatever assignment you give to your computer, it always refers to the data that is before the `.assignment`. Meaning `soup.find_all('tr')` looks for '`tr`'s' in `soup`, and `table.find_all('tr')` looks for `tr`s in `table`.
#
#
# Now let's say that you are especially interested in the 21st row. What do you do? Since computers start counting at zero, you should ask it for row 20 to get to see the 21st row. And since you saved all rows in the `rows` variable, you can actually say 'dear computer, give me row 20' by typing `rows[20]`.

# %%
rows[20]
# Out:
# <tr valign="top">
# <td nowrap="nowrap" scope="row"><a href="/info-finder/reactors/wash2.html">Columbia Generating Station</a><br/>
# 			05000397</td>
# <td align="center">NPF-21</td>
# <td>BWR</td>
# <td>20 miles NNE of Pasco, WA</td>
# <td>Energy Northwest</td>
# <td align="middle">4</td>
# </tr>

# %% [markdown]
# Looking at this row, do you recognize the different cells? Every cell starts with `<td>`, the HTML abbrevation for table data. You can use BeautifulSoup to look for all `td`'s in this 21st row by typing: `rows.find_all('td')`.

# %%
cells = table.find_all('td')
cells
# Out:
# [<td scope="row"><a href="/info-finder/reactors/ano1.html">Arkansas Nuclear 1</a><br/>
#  			05000313</td>,
#  <td align="center">DPR-51</td>,
#  <td>PWR</td>,
#  <td>6 miles WNW of Russellville,  AR</td>,
#  <td>Entergy Nuclear Operations, Inc.</td>,
#  <td align="middle">4</td>,
#  <td scope="row"><a href="/info-finder/reactors/ano2.html">Arkansas Nuclear 2</a><br/>
#  			05000368</td>,
#  <td align="center">NPF-6</td>,
#  <td>PWR</td>,
#  <td>6 miles WNW of Russellville,  AR</td>,
#  <td>Entergy Nuclear Operations, Inc.</td>,
#  <td align="middle">4</td>,
#  <td scope="row"><a href="/info-finder/reactors/bv1.html">Beaver Valley 1</a><br/>
#  			05000334</td>,
#  <td align="center">DPR-66</td>,
#  <td>PWR</td>,
#  <td>17 miles W of McCandless,  PA</td>,
#  <td>FirstEnergy Nuclear Operating Co.</td>,
#  <td align="middle">1</td>,
#  <td scope="row"><a href="/info-finder/reactors/bv2.html">Beaver Valley 2</a><br/>
#  			05000412</td>,
#  <td align="center">NPF-73</td>,
#  <td>PWR</td>,
#  <td>17 miles W of McCandless,  PA</td>,
#  <td>FirstEnergy Nuclear Operating Co.</td>,
#  <td align="middle">1</td>,
#  <td scope="row"><a href="/info-finder/reactors/brai1.html">Braidwood 1</a><br/>
#  			05000456</td>,
#  <td align="center">NPF-72</td>,
#  <td>PWR</td>,
#  			05000250</td>,
#  <td align="center">DPR-31</td>,
#  <td>PWR</td>,
#  <td>20 miles S of Miami,  FL</td>,
#  <td>Florida Power &amp; Light Co.</td>,
#  <td align="middle">2</td>,
#  <td scope="row"><a href="/info-finder/reactors/tp4.html">Turkey Point 4</a><br/>
#  			05000251</td>,
#  <td align="center">DPR-41</td>,
#  <td>PWR</td>,
#  <td>20 miles S of Miami,  FL</td>,
#  <td>Florida Power &amp; Light Co.</td>,
#  <td align="middle">2</td>,
#  <td scope="row"><a href="/info-finder/reactors/vog1.html">Vogtle 1</a><br/>
#  			05000424</td>,
#  <td align="center">NPF-68</td>,
#  <td>PWR</td>,
#  <td>26 miles SE of Augusta,  GA</td>,
#  <td>Southern Nuclear Operating Co.</td>,
#  <td align="middle">2</td>,
#  <td scope="row"><a href="/info-finder/reactors/vog2.html">Vogtle 2</a><br/>
#  			05000425</td>,
#  <td align="center">NPF-81</td>,
#  <td>PWR</td>,
#  <td>26 miles SE of Augusta,  GA</td>,
#  <td>Southern Nuclear Operating Co.</td>,
#  <td align="middle">2</td>,
#  <td scope="row"><a href="/info-finder/reactors/wat3.html">Waterford 3</a><br/>
#  			05000382</td>,
#  <td align="center">NPF-38</td>,
#  <td>PWR</td>,
#  <td>25 miles W of New Orleans,  LA</td>,
#  <td>Entergy Nuclear Operations, Inc.</td>,
#  <td align="middle">4</td>,
#  <td scope="row"><a href="/info-finder/reactors/wb1.html">Watts Bar 1</a><br/>
#  			05000390</td>,
#  <td align="center">NPF-90</td>,
#  <td>PWR</td>,
#  <td>60 miles SW of Knoxville, TN</td>,
#  <td>Tennessee Valley Authority</td>,
#  <td align="middle">2</td>,
#  <td scope="row"><a href="/info-finder/reactors/wb2.html">Watts Bar 2</a><br/>
#  			05000391</td>,
#  <td align="center">NPF-96</td>,
#  <td>PWR</td>,
#  <td>60 miles SW of Knoxville, TN</td>,
#  <td>Tennessee Valley Authority</td>,
#  <td align="middle">2</td>,
#  <td scope="row"><a href="/info-finder/reactors/wc.html">Wolf Creek 1</a><br/>
#  			05000482</td>,
#  <td align="center">NPF-42</td>,
#  <td>PWR</td>,
#  <td>3.5 miles NE of Burlington,  KS</td>,
#  <td>Wolf Creek Nuclear Operating Corp.</td>,
#  <td align="middle">4</td>]

# %% [markdown]
# Just for your information: you can even save the data from the `td`'s to a variable called cells, simply type ` cells = rows[21].find_all('td')`

# %% [markdown]
# Now that you know how to only select 1 certain row, you can probably guess how to select a data cell. Exactly, use `cells[0]` to get the first cell of `cells`.

# %%
cells[0]
# Out:
# <td scope="row"><a href="/info-finder/reactors/ano1.html">Arkansas Nuclear 1</a><br/>
# 			05000313</td>

# %% [markdown]
# It works, but it doesn't look too good, does it? Let's get rid of the HTML bits and pieces around our data. Add `.text` to get the job done.

# %%
cells[0].text
# Out:
# 'Arkansas Nuclear 1\r\n\t\t\t05000313'

# %% [markdown]
# Looks much better, doesn't it?
#
# Unfortunately, there are too many rows in this table to get each cell like we got `Comanche Peak 105000445`. We'll going to have to automate it. Luckily this is one of the big benefits of programming.
#
# Here's what we're going to do:
# 1. create an empty list to be used later
# 2. extract the table from our soup, save it to the `table` variable
# 3. 'loop over' our table....
# 4. ...to save the data we need for each row in the table
# 5. add the selected data to the list
# 6. print the list
#
# At step 3 we'll 'loop over' the table. What does it mean? Well, using a for loop as its called means that we'll give our computer an assignment and have it done **for** every something. It's like your mum when she told you to treat your friends with candy: **for every one of your friend, give them a piece of candy** It's shorter than naming all your friends one by one and repeating the assignment time and time again, right? We're doing exactly the same by telling our computer: **for every row in the table, get the data inside the cells**.

# %%
#for every row in the table... 
for row in table.find_all('tr'):
    #... save the data in each cell inside of that row to cells
    cells = row.find_all(['th', 'td'])
     #... get the data from each of the cells ans save it to a variable
    plantNameDocketNumber = cells[0].text
    licenseNumber = cells[1].text
    reactorType = cells [2].text
    location = cells [3].text
    ownerOperator = cells [4].text
    NRCRegion = cells [5].text
    #... creat a list called rowData containing all variables
    rowData = [plantNameDocketNumber, licenseNumber, reactorType, location, ownerOperator, NRCRegion]
    print (rowData)
# Out:
# ['Plant Name\r\n\t\t\tDocket Number', 'License Number', 'Reactor\r\n\t\t\tType', 'Location', 'Owner/Operator', 'NRC Region']
# ['Arkansas Nuclear 1\r\n\t\t\t05000313', 'DPR-51', 'PWR', '6 miles WNW of Russellville,\xa0\xa0AR', 'Entergy Nuclear Operations, Inc.', '4']
# ['Arkansas Nuclear 2\r\n\t\t\t05000368', 'NPF-6', 'PWR', '6 miles WNW of Russellville,\xa0\xa0AR', 'Entergy Nuclear Operations, Inc.', '4']
# ['Beaver Valley 1\r\n\t\t\t05000334', 'DPR-66', 'PWR', '17 miles W of McCandless,\xa0\xa0PA', 'FirstEnergy Nuclear Operating Co.', '1']
# ['Beaver Valley 2\r\n\t\t\t05000412', 'NPF-73', 'PWR', '17 miles W of McCandless,\xa0\xa0PA', 'FirstEnergy Nuclear Operating Co.', '1']
# ['Braidwood 1\r\n\t\t\t05000456', 'NPF-72', 'PWR', '20 miles SSW of Joliet,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['Braidwood 2\r\n\t\t\t05000457', 'NPF-77', 'PWR', '20 miles SSW of Joliet,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['Browns Ferry 1\r\n\t\t\t05000259', 'DPR-33', 'BWR', '32 miles W of Huntsville, AL', 'Tennessee Valley Authority', '2']
# ['Browns Ferry 2\r\n\t\t\t05000260', 'DPR-52', 'BWR', '32 miles W of Huntsville, AL', 'Tennessee Valley Authority', '2']
# ['Browns Ferry 3\r\n\t\t\t05000296', 'DPR-68', 'BWR', '32 miles W of Huntsville, AL', 'Tennessee Valley Authority', '2']
# ['Brunswick 1\r\n\t\t\t05000325', 'DPR-71', 'BWR', '30 miles S of Wilmington, NC', 'Duke Energy Progress, LLC', '2']
# ['Brunswick 2\r\n\t\t\t05000324', 'DPR-62', 'BWR', '30 miles S of Wilmington, NC', 'Duke Energy Progress, LLC', '2']
# ['Byron 1\r\n\t\t\t05000454', 'NPF-37', 'PWR', '17 miles SW of Rockford,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['Byron 2\r\n\t\t\t05000455', 'NPF-66', 'PWR', '17 miles SW of Rockford,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['Callaway\r\n\t\t\t05000483', 'NPF-30', 'PWR', '25 miles ENE of Jefferson City, MO', 'Ameren UE', '4']
# ['Calvert Cliffs 1\r\n\t\t\t05000317', 'DPR-53', 'PWR', '40 miles S of Annapolis,\xa0\xa0MD', 'Constellation Energy', '1']
# ['Calvert Cliffs 2\r\n\t\t\t05000318', 'DPR-69', 'PWR', '40 miles S of Annapolis,\xa0\xa0MD', 'Constellation Energy', '1']
# ['Catawba 1\r\n\t\t\t05000413', 'NPF-35', 'PWR', '18 miles S of Charlotte, NC', 'Duke Energy Carolinas, LLC', '2']
# ['Catawba 2\r\n\t\t\t05000414', 'NPF-52', 'PWR', '18 miles S of Charlotte, NC', 'Duke Energy Carolinas, LLC', '2']
# ['Clinton\r\n\t\t\t05000461', 'NPF-62', 'BWR', '23 miles SSE of Bloomington, IL', 'Exelon Generation Co., LLC', '3']
# ['Columbia Generating Station\r\n\t\t\t05000397', 'NPF-21', 'BWR', '20 miles NNE of Pasco, WA', 'Energy Northwest', '4']
# ['Comanche Peak 1\r\n\t\t\t05000445', 'NPF-87', 'PWR', '40 miles SW of Fort Worth, TX', 'TEX Operations Company LLC', '4']
# ['Comanche Peak 2\r\n\t\t\t05000446', 'NPF-89', 'PWR', '40 miles SW of Fort Worth, TX', 'TEX Operations Company LLC', '4']
# ['Cooper\r\n\t\t\t05000298', 'DPR-46', 'BWR', '23 miles S of Nebraska City,\xa0\xa0NE', 'Nebraska Public Power District', '4']
# ['D.C. Cook 1\r\n\t\t\t05000315', 'DPR-58', 'PWR', '13 miles S of Benton Harbor,\xa0\xa0MI', 'Indiana/Michigan Power Co.', '3']
# ['D.C. Cook 2 \r\n\t\t\t05000316', 'DPR-74', 'PWR', '13 miles S of Benton Harbor,\xa0\xa0MI', 'Indiana/Michigan Power Co.', '3']
# ['Davis-Besse\r\n\t\t\t05000346', 'NPF-3', 'PWR', '21 miles ESE of Toledo,\xa0\xa0OH', 'FirstEnergy Nuclear Operating Co.', '3']
# ['Diablo Canyon 1\r\n\t\t\t05000275', 'DPR-80', 'PWR', '12 miles WSW of San Luis Obispo,\xa0\xa0CA', 'Pacific Gas & Electric Co.', '4']
# ['Diablo Canyon 2\r\n\t\t\t05000323', 'DPR-82', 'PWR', '12 miles WSW of San Luis Obispo,\xa0\xa0CA', 'Pacific Gas & Electric Co.', '4']
# ['Dresden 2\r\n\t\t\t05000237', 'DPR-19', 'BWR', '25 miles SW of Joliet, IL', 'Exelon Generation Co., LLC', '3']
# ['Dresden 3\r\n\t\t\t05000249', 'DPR-25', 'BWR', '25 miles SW of Joliet, IL', 'Exelon Generation Co., LLC', '3']
# ['Duane Arnold\r\n\t\t\t05000331', 'DPR-49', 'BWR', '8 miles NW of Cedar Rapids,\xa0\xa0IA', 'NextEra Energy Duane Arnold, LLC', '3']
# ['Farley 1\r\n\t\t\t05000348', 'NPF-2', 'PWR', '18 miles E of Dothan,\xa0\xa0AL', 'Southern Nuclear Operating Co.', '2']
# ['Farley 2\r\n\t\t\t05000364', 'NPF-8', 'PWR', '18 miles E of Dothan,\xa0\xa0AL', 'Southern Nuclear Operating Co.', '2']
# ['Fermi 2\r\n\t\t\t05000341', 'NPF-43', 'BWR', '25 miles NE of Toledo,\xa0\xa0OH', 'DTE Electric Company', '3']
# ['FitzPatrick\r\n\t\t\t05000333', 'DPR-59', 'BWR', '6 miles NE of Oswego,\xa0\xa0NY', 'Exelon FitzPatrick, LLC/Exelon Generation Company, LLC', '1']
# ['Ginna\r\n\t\t\t05000244', 'DPR-18', 'PWR', '20 miles NE of Rochester,\xa0\xa0NY', 'Constellation Energy', '1']
# ['Grand Gulf 1\r\n\t\t\t05000416', 'NPF-29', 'BWR', '20 miles S of Vicksburg,\xa0\xa0MS', 'Entergy Nuclear Operations, Inc.', '4']
# ['Hatch 1\r\n\t\t\t05000321', 'DPR-57', 'BWR', '20 miles S of Vidalia, GA', 'Southern Nuclear Operating Co., Inc.', '2']
# ['Hatch 2\r\n\t\t\t05000366', 'NPF-5', 'BWR', '20 miles S of Vidalia, GA', 'Southern Nuclear Operating Co., Inc.', '2']
# ['Hope Creek 1\r\n\t\t\t05000354', 'NPF-57', 'BWR', '18 miles SE of Wilmington,\xa0\xa0DE', 'PSEG Nuclear, LLC', '1']
# ['Indian Point 3\r\n\t\t\t05000286', 'DPR-64', 'PWR', '24 miles N of New York City,\xa0\xa0NY', 'Entergy Nuclear Operations, Inc.', '1']
# ['La Salle 1\r\n\t\t\t05000373', 'NPF-11', 'BWR', '11 miles SE of Ottawa,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['La Salle 2\r\n\t\t\t05000374', 'NPF-18', 'BWR', '11 miles SE of Ottawa,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['Limerick 1\r\n\t\t\t05000352', 'NPF-39', 'BWR', '21 miles NW of Philadelphia,\xa0\xa0PA', 'Exelon Generation Co., LLC', '1']
# ['Limerick 2\r\n\t\t\t05000353', 'NPF-85', 'BWR', '21 miles NW of Philadelphia,\xa0\xa0PA', 'Exelon Generation Co., LLC', '1']
# ['McGuire 1\r\n\t\t\t05000369', 'NPF-9', 'PWR', '17 miles N of Charlotte,\xa0\xa0NC', 'Duke Energy Carolinas, LLC', '2']
# ['McGuire 2\r\n\t\t\t05000370', 'NPF-17', 'PWR', '17 miles N of Charlotte,\xa0\xa0NC', 'Duke Energy Carolinas, LLC', '2']
# ['Millstone 2\r\n\t\t\t05000336', 'DPR-65', 'PWR', '3.2 miles WSW of New London,\xa0\xa0CT', 'Dominion Generation', '1']
# ['Millstone 3\r\n\t\t\t05000423', 'NPF-49', 'PWR', '3.2 miles WSW of New London,\xa0\xa0CT', 'Dominion Generation', '1']
# ['Monticello\r\n\t\t\t05000263', 'DPR-22', 'BWR', '35 miles NW of Minneapolis,\xa0\xa0MN', 'Northern States Power Company – Minnesota', '3']
# ['Nine Mile Point 1\r\n\t\t\t05000220', 'DPR-63', 'BWR', '6 miles NE of Oswego,\xa0\xa0NY', 'Constellation Energy', '1']
# ['Nine Mile Point 2\r\n\t\t\t05000410', 'NPF-69', 'BWR', '6 miles NE of Oswego,\xa0\xa0NY', 'Constellation Energy', '1']
# ['North Anna 1\r\n\t\t\t05000338', 'NPF-4', 'PWR', '40 miles NW of Richmond,\xa0\xa0VA', 'Dominion Generation', '2']
# ['North Anna 2\r\n\t\t\t05000339', 'NPF-7', 'PWR', '40 miles NW of Richmond,\xa0\xa0VA', 'Dominion Generation', '2']
# ['Oconee 1\r\n\t\t\t05000269', 'DPR-38', 'PWR', '30 miles W of Greenville,\xa0\xa0SC', 'Duke Energy Carolinas, LLC', '2']
# ['Oconee 2\r\n\t\t\t05000270', 'DPR-47', 'PWR', '30 miles W of Greenville,\xa0\xa0SC', 'Duke Energy Carolinas, LLC', '2']
# ['Oconee 3\r\n\t\t\t05000287', 'DPR-55', 'PWR', '30 miles W of Greenville,\xa0\xa0SC', 'Duke Energy Carolinas, LLC', '2']
# ['Palisades\r\n\t\t\t05000255', 'DPR-20', 'PWR', '5 miles S of South Haven,\xa0\xa0MI', 'Entergy Nuclear Operations, Inc.', '3']
# ['Palo Verde 1\r\n\t\t\t05000528', 'NPF-41', 'PWR', '50 miles W of Phoenix,\xa0\xa0AZ', 'Arizona Public Service Co.', '4']
# ['Palo Verde 2\r\n\t\t\t05000529', 'NPF-51', 'PWR', '50 miles W of Phoenix,\xa0\xa0AZ', 'Arizona Public Service Co.', '4']
# ['Palo Verde 3\r\n\t\t\t05000530', 'NPF-74', 'PWR', '50 miles W of Phoenix,\xa0\xa0AZ', 'Arizona Public Service Co.', '4']
# ['Peach Bottom 2\r\n\t\t\t05000277', 'DPR-44', 'BWR', '17.9 miles S of Lancaster,\xa0\xa0PA', 'Exelon Generation Co., LLC', '1']
# ['Peach Bottom 3\r\n\t\t\t05000278', 'DPR-56', 'BWR', '17.9 miles S of Lancaster,\xa0\xa0PA', 'Exelon Generation Co., LLC', '1']
# ['Perry 1\r\n\t\t\t05000440', 'NPF-58', 'BWR', '35 miles NE of Cleveland, OH', 'FirstEnergy Nuclear Operating Co.', '3']
# ['Point Beach 1\r\n\t\t\t05000266', 'DPR-24', 'PWR', '13 miles NNW of Manitowoc,\xa0\xa0WI', 'NextEra Energy Point Beach, LLC', '3']
# ['Point Beach 2\r\n\t\t\t05000301', 'DPR-27', 'PWR', '13 miles NNW of Manitowoc,\xa0\xa0WI', 'NextEra Energy Point Beach, LLC', '3']
# ['Prairie Island 1\r\n\t\t\t05000282', 'DPR-42', 'PWR', '28 miles SE of Minneapolis,\xa0\xa0MN', 'Northern States Power Company – Minnesota', '3']
# ['Prairie Island 2\r\n\t\t\t05000306', 'DPR-60', 'PWR', '28 miles SE of Minneapolis,\xa0\xa0MN', 'Northern States Power Company – Minnesota', '3']
# ['Quad Cities 1\r\n\t\t\t05000254', 'DPR-29', 'BWR', '20 miles NE of Moline,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['Quad Cities 2\r\n\t\t\t05000265', 'DPR-30', 'BWR', '20 miles NE of Moline,\xa0\xa0IL', 'Exelon Generation Co., LLC', '3']
# ['River Bend 1\r\n\t\t\t05000458', 'NPF-47', 'BWR', '24 miles NNW of Baton Rouge,\xa0\xa0LA', 'Entergy Nuclear Operations, Inc.', '4']
# ['Robinson 2\r\n\t\t\t05000261', 'DPR-23', 'PWR', '26 miles NW of Florence,\xa0\xa0SC', 'Duke Energy Progress, LLC', '2']
# ['Saint Lucie 1\r\n\t\t\t05000335', 'DPR-67', 'PWR', '10 miles SE of Ft. Pierce,\xa0\xa0FL', 'Florida Power & Light Co.', '2']
# ['Saint Lucie 2\r\n\t\t\t05000389', 'NPF-16', 'PWR', '10 miles SE of Ft. Pierce,\xa0\xa0FL', 'Florida Power & Light Co.', '2']
# ['Salem 1\r\n\t\t\t05000272', 'DPR-70', 'PWR', '18 miles S of Wilmington,\xa0\xa0DE', 'PSEG Nuclear, LLC', '1']
# ['Salem 2\r\n\t\t\t05000311', 'DPR-75', 'PWR', '18 miles S of Wilmington,\xa0\xa0DE', 'PSEG Nuclear, LLC', '1']
# ['Seabrook 1\r\n\t\t\t05000443', 'NPF-86', 'PWR', '13 miles S of Portsmouth,\xa0\xa0NH', 'NextEra Energy Seabrook, LLC', '1']
# ['Sequoyah 1\r\n\t\t\t05000327', 'DPR-77', 'PWR', '16 miles NE of Chattanooga,\xa0\xa0TN', 'Tennessee Valley Authority', '2']
# ['Sequoyah 2\r\n\t\t\t05000328', 'DPR-79', 'PWR', '16 miles NE of Chattanooga,\xa0\xa0TN', 'Tennessee Valley Authority', '2']
# ['Shearon Harris 1\r\n\t\t\t05000400', 'NPF-63', 'PWR', '20 miles SW of Raleigh,\xa0\xa0NC', 'Duke Energy Progress, LLC', '2']
# ['South Texas 1\r\n\t\t\t05000498', 'NPF-76', 'PWR', '90 miles SW of Houston, TX', 'STP Nuclear Operating Co.', '4']
# ['South Texas 2\r\n\t\t\t05000499', 'NPF-80', 'PWR', '90 miles SW of Houston, TX', 'STP Nuclear Operating Co.', '4']
# ['Summer\r\n\t\t\t05000395', 'NPF-12', 'PWR', '26 miles NW of Columbia,\xa0\xa0SC', 'South Carolina Electric & Gas Co.', '2']
# ['Surry 1\r\n\t\t\t05000280', 'DPR-32', 'PWR', '17 miles NW of Newport News,\xa0\xa0VA', 'Dominion Generation', '2']
# ['Surry 2\r\n\t\t\t05000281', 'DPR-37', 'PWR', '17 miles NW of Newport News,\xa0\xa0VA', 'Dominion Generation', '2']
# ['Susquehanna 1\r\n\t\t\t05000387', 'NPF-14', 'BWR', '70 miles NE of Harrisburg, PA', 'Susquehanna Nuclear, LLC', '1']
# ['Susquehanna 2\r\n\t\t\t05000388', 'NPF-22', 'BWR', '70 miles NE of Harrisburg, PA', 'Susquehanna Nuclear, LLC', '1']
# ['Turkey Point 3\r\n\t\t\t05000250', 'DPR-31', 'PWR', '20 miles S of Miami,\xa0\xa0FL', 'Florida Power & Light Co.', '2']
# ['Turkey Point 4\r\n\t\t\t05000251', 'DPR-41', 'PWR', '20 miles S of Miami,\xa0\xa0FL', 'Florida Power & Light Co.', '2']
# ['Vogtle 1\r\n\t\t\t05000424', 'NPF-68', 'PWR', '26 miles SE of Augusta,\xa0\xa0GA', 'Southern Nuclear Operating Co.', '2']
# ['Vogtle 2\r\n\t\t\t05000425', 'NPF-81', 'PWR', '26 miles SE of Augusta,\xa0\xa0GA', 'Southern Nuclear Operating Co.', '2']
# ['Waterford 3\r\n\t\t\t05000382', 'NPF-38', 'PWR', '25 miles W of New Orleans,\xa0\xa0LA', 'Entergy Nuclear Operations, Inc.', '4']
# ['Watts Bar 1\r\n\t\t\t05000390', 'NPF-90', 'PWR', '60 miles SW of Knoxville, TN', 'Tennessee Valley Authority', '2']
# ['Watts Bar 2\r\n\t\t\t05000391', 'NPF-96', 'PWR', '60 miles SW of Knoxville, TN', 'Tennessee Valley Authority', '2']
# ['Wolf Creek 1\r\n\t\t\t05000482', 'NPF-42', 'PWR', '3.5 miles NE of Burlington,\xa0\xa0KS', 'Wolf Creek Nuclear Operating Corp.', '4']

# %% [markdown]
# Congrats! You just wrote your very first scraper - well done!
#
# ## Saving the scraped data
#
# Now, off course having your data printed inside the notebook is nice. But it would be even beter to store the data in a CSV file. Remember that I explained what we'd actually be doing? Off course things are a bit more complicated; let me explain. Here's what I told you before:
#
# - tell your computer which site to visit: where do you want to download data from?
#     - we'll be using the `requests` library to requests webpages
# - save the webpage (the html-page) to the computer
#     - this too will be done with library `requests`
# - from the webpage, select the data you want to have
#     - we'll be using `BeautifulSoup` to do this
# - write the selection to a csv-file
#     - this is done with the `csv` library
#
# Here's what the code will actually do:
# 1. Create a CSV file to save data in
# 2. Create a CSV writer to write data with to the CSV file
# 3. Tell your computer which site(s) to visit
# 4. Get the webpage
# 5. Select data from the webpage
# 6. Write data with the CSV writer to the CSV file
# 7. Save file
#
# ## Save data to CSV
#
# Here's how to save data to a CSV file using the CSV library - the process involves a couple steps:
# 1. create a file, open it, make sure it's 'writeable', use `open('filename.csv', 'w', encoding='utf8', newline='')`
# 2. create a writer, you'll need a writer if you want to write data to the file, use `csv.writer(filename, delimiter=',')`
# 3. write data to the file using the writer, use `writer.writerow([data])`
#
# Off course you can repeat step 3 as often as necessary.

# %%
#create file, make sure it's writeable, set some defaults
f = open('PowerReactorsUnits.csv', 'w', encoding='utf8', newline='')

#create a writer to write data to the CSV file
import csv
writer = csv.writer(f, delimiter=',')

#write the first row of data to the file
writer.writerow(['plantNameDocketNumber', 'licenseNumber', 'reactorType', 'location', 'ownerOperator', 'NRCRegion'])
# Out:
# 82

# %% [markdown]
# Using the `ls` command you can see that a new file was created.

# %%
ls
# Out:
#  O volume na unidade C é Windows-SSD
#  O Número de Série do Volume é 101A-500C
#
#  Pasta de C:\Users\micka\pythonforjounalists\3 Scrap data
#
# 26/01/2021  20:59    <DIR>          .
# 26/01/2021  20:59    <DIR>          ..
# 14/01/2021  19:18    <DIR>          .ipynb_checkpoints
# 14/01/2021  19:18           327.116 4 Scrape data - Complete.ipynb
# 26/01/2021  20:59           151.209 4 Scrape data.ipynb
# 26/01/2021  20:59                 0 PowerReactorsUnits.csv
# 14/01/2021  19:18             8.313 scrapedData single header.csv
# 14/01/2021  19:18             9.390 scrapedData.csv
#                5 arquivo(s)        496.028 bytes
#                3 pasta(s)   391.164.559.360 bytes disponíveis

# %% [markdown]
# ## The scraper
# Before we broke our essay scraper into sentences before. Now I'll be putting all these sentences together. This way, you can get a good overview of what a scraper could look like. Here's a list of what we need to do, in the exact order:
# 1. Create a CSV file, open it, make it writeable
# 2. Create a CSV writer to write data
# 3. Write the column headers to the file
# 4. Tell your computer which site(s) to visit
# 5. Get the webpage
# 6. Select data from the webpage
# 7. Write data with the CSV writer to the CSV file
# 8. Save file

# %%
#create file, make sure it's writeable, set some defaults
f = open('powerReactorsUnits.csv', 'w', encoding='utf8', newline='')

#create a writer to write data to the CSV file
import csv
writer = csv.writer(f, delimiter=',')

#write the first row of data to the file
writer.writerow(['plantNameDocketNumber', 'licenseNumber', 'reactorType', 'location', 'ownerOperator', 'NRCRegion'])

url = 'https://www.nrc.gov/reactors/operating/list-power-reactor-units.html'
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find('table')

#for every row in the table... 
for row in table.find_all('tr'):
    #... save the data in each cell inside of that row to cells
    cells = row.find_all(['th', 'td'])
     #... get the data from each of the cells ans save it to a variable
    plantNameDocketNumber = cells[0].text
    licenseNumber = cells[1].text
    reactorType = cells [2].text
    location = cells [3].text
    ownerOperator = cells [4].text
    NRCRegion = cells [5].text
    #... creat a list called rowData containing all variables
    rowData = [plantNameDocketNumber, licenseNumber, reactorType, location, ownerOperator, NRCRegion]
    writer.writerow(rowData)

# %% [markdown]
# If you want to check if everything worked as it's supposed to, you can import the ScrapedData.csv file as a dataframe using `pd.read_csv('filename.csv')`. Look at the dataframe to see if there's data in the file. Using `df.shape` you can even quickly check if there is as much data in the file as you'd expect.

# %%
df = pd.read_csv('PowerReactorsUnits.csv')
df
# Out:
#                    plantNameDocketNumber   licenseNumber  \
# 0      Plant Name\r\n\t\t\tDocket Number  License Number
# 1   Arkansas Nuclear 1\r\n\t\t\t05000313          DPR-51
# 2   Arkansas Nuclear 2\r\n\t\t\t05000368           NPF-6
# 3      Beaver Valley 1\r\n\t\t\t05000334          DPR-66
# 4      Beaver Valley 2\r\n\t\t\t05000412          NPF-73
# ..                                   ...             ...
# 74       Saint Lucie 2\r\n\t\t\t05000389          NPF-16
# 75             Salem 1\r\n\t\t\t05000272          DPR-70
# 76             Salem 2\r\n\t\t\t05000311          DPR-75
# 77          Seabrook 1\r\n\t\t\t05000443          NPF-86
# 78          Sequoyah 1\r\n\t\t\t05000327          DPR-77
#
#               reactorType                          location  \
# 0   Reactor\r\n\t\t\tType                          Location
# 1                     PWR  6 miles WNW of Russellville,  AR
# 2                     PWR  6 miles WNW of Russellville,  AR
# 3                     PWR     17 miles W of McCandless,  PA
# 4                     PWR     17 miles W of McCandless,  PA
# ..                    ...                               ...
# 74                    PWR    10 miles SE of Ft. Pierce,  FL
# 75                    PWR     18 miles S of Wilmington,  DE
# 76                    PWR     18 miles S of Wilmington,  DE
# 77                    PWR     13 miles S of Portsmouth,  NH
# 78                    PWR   16 miles NE of Chattanooga,  TN
#
#                         ownerOperator   NRCRegion
# 0                      Owner/Operator  NRC Region
# 1    Entergy Nuclear Operations, Inc.           4
# 2    Entergy Nuclear Operations, Inc.           4
# 3   FirstEnergy Nuclear Operating Co.           1
# 4   FirstEnergy Nuclear Operating Co.           1
# ..                                ...         ...
# 74          Florida Power & Light Co.           2
# 75                  PSEG Nuclear, LLC           1
# 76                  PSEG Nuclear, LLC           1
# 77       NextEra Energy Seabrook, LLC           1
# 78         Tennessee Valley Authority           2
#
# [79 rows x 6 columns]

# %% [markdown]
# `df.shape` will give you the number of rows and columns of the dataframe. A quick way to check if really everything that should be in the CSV file is there.

# %%
df.shape
# Out:
# (79, 6)

# %% [markdown]
# Note that the headers are in the dataset twice:
# while scraping we added header; but we also scraped the headers since the headers are in the first row of the table and we scraped all table rows...
#
# Now what?
#
# You can easily delete a row by using ``df.drop(df.index[N])``, to drop the Nth row by index number.
#
# To make sure you get the index number right, why not print the first rows once more? We're in a notebook after all... You can use ``df.head()``

# %%
df.head()
# Out:
#                   plantNameDocketNumber   licenseNumber  \
# 0     Plant Name\r\n\t\t\tDocket Number  License Number
# 1  Arkansas Nuclear 1\r\n\t\t\t05000313          DPR-51
# 2  Arkansas Nuclear 2\r\n\t\t\t05000368           NPF-6
# 3     Beaver Valley 1\r\n\t\t\t05000334          DPR-66
# 4     Beaver Valley 2\r\n\t\t\t05000412          NPF-73
#
#              reactorType                          location  \
# 0  Reactor\r\n\t\t\tType                          Location
# 1                    PWR  6 miles WNW of Russellville,  AR
# 2                    PWR  6 miles WNW of Russellville,  AR
# 3                    PWR     17 miles W of McCandless,  PA
# 4                    PWR     17 miles W of McCandless,  PA
#
#                        ownerOperator   NRCRegion
# 0                     Owner/Operator  NRC Region
# 1   Entergy Nuclear Operations, Inc.           4
# 2   Entergy Nuclear Operations, Inc.           4
# 3  FirstEnergy Nuclear Operating Co.           1
# 4  FirstEnergy Nuclear Operating Co.           1

# %% [markdown]
# Looking at these first 5 rows, you'll find that you want to delete the row with indexnumber 0. As stated before, you can use ``df.drop``. By default Pandas will create and return a copy of your dataset, and delete the row of your choosing in that copy. This means that the original will still include dropped row.
#
# Consider this a safety belt when deleting data using Pandas. ;)

# %% [markdown]
# To delete the first row in the original dataset - and not in a copy that Pandas will return to you; you'll need to use ``inplace=True``. The full command becomes: ``df.drop(df.index[0], inplace=True)``.
#
# ``inplace=True`` will delete the row in the original dataset, and won't return anything. Try it:

# %% [markdown]
# To see that it worked, request the head of the dataframe...

# %% [markdown]
# If you want to you can save this cleaned version, by using ``df.to_csv()``...

# %% [markdown]
# Well done, happy web scraping!
